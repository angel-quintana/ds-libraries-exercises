# %% [markdown]
# # Ex 1

# %%
import pandas as pd
import numpy as np

# %%
#3. Create a function named get_db_url. 
def get_db_url(username, host, password, database_name):
    return f'mysql+pymysql://{username}:{password}@{host}/{database_name}'

# %%
get_db_url('lemon', 'lime', 'soda' , 'drink')
# Out:
# 'mysql+pymysql://lemon:soda@lime/drink'

# %%
#4. Use your function to obtain a connection to the employees database.
from env import host, username, password
url = get_db_url(username, host, password, 'employees')
pd.read_sql('select * from employees limit 5', url)
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
#5.a. Intentionally make a typo in the database url. What kind of error message do you see?
pd.read_sql('select * from employees limit 5', url) #giant operational error

# %%
#5.b. Intentionally make an error in your SQL query. What does the error message look like?
# giant programming error 'table doesnt exist'

# %%
#6. Read the employees and titles tables into two separate DataFrames.
df_employees= pd.DataFrame(pd.read_sql('select * from employees', url))
df_employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
df_titles= pd.DataFrame(pd.read_sql('select * from titles', url))
df_titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
#7. How many rows and columns do you have in each DataFrame? Is that what you expected?
# the columns match the tables printed from mysql. as do the rows

# %%
#8. Display the summary statistics for each DataFrame.

# %%
df_employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
df_titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
#9. How many unique titles are in the titles DataFrame?
len(df_titles.title.value_counts())\
# Out:
# 7

# %%
#10. What is the oldest date in the to_date column?
df_titles.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %%
#11. What is the most recent date in the to_date column?
df_titles.to_date.max()
# Out:
# datetime.date(9999, 1, 1)

# %% [markdown]
# # Ex 2

# %%
#1.Copy the users and roles DataFrames from the examples above.

# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users

# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
#2. What is the result of using a right join on the DataFrames?
pd.merge(users, roles, how='right', left_on='role_id', right_on='id') #includes all rows from roles
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %%
#3. What is the result of using an outer join on the DataFrames?
pd.merge(users, roles, how='outer', left_on='role_id', right_on='id') #includes all rows from both
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %%
#4. What happens if you drop the foreign keys from the DataFrames and try to merge them?
pd.merge(users, roles, how='outer') #returned one df after another along similar keys
# Out:
#    id       name  role_id
# 0   1        bob      1.0
# 1   2        joe      2.0
# 2   3      sally      3.0
# 3   4       adam      3.0
# 4   5       jane      NaN
# 5   6       mike      NaN
# 6   1      admin      NaN
# 7   2     author      NaN
# 8   3   reviewer      NaN
# 9   4  commenter      NaN

# %%
#5. Load the mpg dataset from PyDataset.
# Load the dataset and store it in the variable mpg.

from pydataset import data
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
#7. How many rows and columns are in the dataset?
mpg.shape
# Out:
# (234, 11)

# %%
#8. Check out your column names and perform any cleanup you may want on them.
mpg = mpg.rename(columns={'fl': 'fuel'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
#9. Display the summary statistics for the dataset.
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#10. How many different manufacturers are there?
mpg.manufacturer.describe() #15 unique
# Out:
# count       234
# unique       15
# top       dodge
# freq         37
# Name: manufacturer, dtype: object

# %%
len(mpg.groupby('manufacturer'))
# Out:
# 15

# %%
#11. How many different models are there?
mpg.model.describe() #38 unique
# Out:
# count             234
# unique             38
# top       caravan 2wd
# freq               11
# Name: model, dtype: object

# %%
#12. Create a column named mileage_difference like you did in the DataFrames exercises;
#    this column should contain the difference between highway and city mileage for each car.
mpg['mileage_difference'] = mpg.hwy - mpg.cty

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class  mileage_difference
# 1    compact                  11
# ...

# %%
#13. Create a column named average_mileage like you did in the DataFrames exercises;
#    this is the mean of the city and highway mileage.
mpg['average_mileage'] = (mpg.hwy + mpg.cty)/2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class  mileage_difference  average_mileage
# ...

# %%
sorted(mpg.trans.unique())[-2:]
# Out:
# ['manual(m5)', 'manual(m6)']

# %%
mask = mpg.trans.str.contains('auto')
mask
# Out:
# 1       True
# 2      False
# 3      False
# 4       True
# 5       True
#        ...
# 230     True
# 231    False
# 232     True
# 233    False
# 234     True
# Name: trans, Length: 234, dtype: bool

# %%
#14. Create a new column on the mpg dataset named is_automatic that 
#    holds boolean values denoting whether the car has an automatic transmission.
mpg['is_automatic'] = np.where(mpg.trans.str.contains('auto') , 'auto', 'manual')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30    p
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26    p
#
#      class  mileage_difference  average_mileage is_automatic
# 1  compact                  11             23.5         auto
# 2  compact                   8             25.0       manual
# 3  compact                  11             25.5       manual
# 4  compact                   9             25.5         auto
# 5  compact                  10             21.0         auto

# %%
#15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?
mpg.groupby('manufacturer').average_mileage.mean().nlargest()
# Out:
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# Name: average_mileage, dtype: float64

# %%
#16. Do automatic or manual cars have better miles per gallon?
mpg.groupby('is_automatic').average_mileage.mean()
# Out:
# is_automatic
# auto      19.130573
# manual    22.227273
# Name: average_mileage, dtype: float64

# %% [markdown]
# # ex 3

# %%
#1. Use your get_db_url function to help you explore the data from the chipotle database.
from env import host, username, password
url_chipotle = get_db_url(username, host, password, 'chipotle')
orders = pd.DataFrame(pd.read_sql('select * from orders', url_chipotle))
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
def extract_price(string):
    cleaned_price = (string.replace('$', ''))
    return cleaned_price

# %%
#2. What is the total price for each order?
orders['item_price'] = orders['item_price'].apply(extract_price) 
orders['item_price'] = orders['item_price'].astype(float)

# %%
orders.groupby('order_id').item_price.sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %%
#3. What are the most popular 3 items?
orders.groupby('item_name').quantity.sum().nlargest(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %%
#4. Which item has produced the most revenue?
quantities=orders.groupby('item_name').quantity.sum()
orders.groupby('item_name').quantity.sum().nlargest(3)
# Out:
# 50

# %%
orders['rev_per_item']= orders.quantity * orders.item_price
orders.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price  rev_per_item
# 0        2.39          2.39
# 1        3.39          3.39
# ...

# %%
orders.groupby('item_name').rev_per_item.sum().nlargest(1)
# Out:
# item_name
# Chicken Bowl    8044.63
# Name: rev_per_item, dtype: float64

# %%
#5. Join the employees and titles DataFrames together.
df_employees= pd.DataFrame(pd.read_sql('select * from employees', url))
df_employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
df_titles_and_employees= pd.DataFrame(pd.read_sql('select * from titles join employees using(emp_no)', url))
df_titles_and_employees
# Out:
#         emp_no            title   from_date     to_date  birth_date  \
# 0        10001  Senior Engineer  1986-06-26  9999-01-01  1953-09-02
# 1        10002            Staff  1996-08-03  9999-01-01  1964-06-02
# 2        10003  Senior Engineer  1995-12-03  9999-01-01  1959-12-03
# 3        10004         Engineer  1986-12-01  1995-12-01  1954-05-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01  1954-05-01
# ...        ...              ...         ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29  1961-08-03
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01  1961-08-03
# 443305  499998     Senior Staff  1998-12-27  9999-01-01  1956-09-05
# 443306  499998            Staff  1993-12-27  1998-12-27  1956-09-05
# 443307  499999         Engineer  1997-11-30  9999-01-01  1958-05-01
#
#        first_name last_name gender   hire_date
# 0          Georgi   Facello      M  1986-06-26
# 1         Bezalel    Simmel      F  1985-11-21
# ...

# %%
#6. For each title, find the hire date of the employee that was hired most recently with that title.
df_titles_and_employees.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %%
#7. Write the code necessary to create a cross tabulation of the number of titles by department. 
#(Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)
